# %% [markdown]
# <a href="https://colab.research.google.com/github/jrkirschner2004-ctrl/ML-F2025/blob/main/ICA5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("plot-data.csv")

plt.scatter(data["x"], data[" y"], marker="o")
plt.xlabel("Cycles to Failure, N")
plt.xscale('log')
plt.ylabel("Stress ksi")
# Out:
# Text(0, 0.5, 'Stress ksi')
